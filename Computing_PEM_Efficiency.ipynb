# %%
import numpy as np
import matplotlib.pyplot as plt
# from scipy.special import jv as Jv
from EPPE_Simulator import retardance_efficiency as e

# %%
wavs = np.arange(590,940)

# %%
def s(wavs):
    return np.ones_like(wavs)

# %%
# def e(wavs, wavCent):
#     return Jv(2,np.pi*wavCent/wavs)*np.sqrt(2)

# %%
totals = np.array([np.mean(e(wavs, wavCent)) for wavCent in wavs])
wavCent = wavs[np.argmax(totals)]
wavCent
# Out:
# 714

# %%
plt.plot(wavs, e(wavs, wavCent))
plt.xlabel('Wavelength (nm)')
plt.ylabel('PEM Retardance Efficiency (0 to 1)')
plt.savefig('/home/taylor/Downloads/PEM_retardance.png', dpi=400, bbox_inches='tight')
plt.show()

# %%
np.mean(e(wavs, wavCent))
# Out:
# 0.5975548193418322

# %%
np.max(e(wavs, wavCent))
# Out:
# 0.6880130231754793

# %%
plt.plot(wavs, e(wavs, wavCent)/np.max(e(wavs, wavCent)))
plt.show()
